# %%
full = {'colsample_bytree': 0.585084816675222, 'gamma': 3.0609644400133007, 'max_depth': 5.0, 'min_child_weight': 4.0, 'reg_alpha': 171.0, 'reg_lambda': 0.8850978829895682}
full
# Out:
# {'colsample_bytree': 0.585084816675222,
#  'gamma': 3.0609644400133007,
#  'max_depth': 5.0,
#  'min_child_weight': 4.0,
#  'reg_alpha': 171.0,
#  'reg_lambda': 0.8850978829895682}

# %%
main = {'colsample_bytree': 0.7163580641592272, 'gamma': 7.845151938193131, 'max_depth': 9.0, 'min_child_weight': 10.0, 'reg_alpha': 80.0, 'reg_lambda': 0.5849619075986845}
main
# Out:
# {'colsample_bytree': 0.7163580641592272,
#  'gamma': 7.845151938193131,
#  'max_depth': 9.0,
#  'min_child_weight': 10.0,
#  'reg_alpha': 80.0,
#  'reg_lambda': 0.5849619075986845}

# %%
others = {'colsample_bytree': 0.542121153860698, 'gamma': 5.465775116244733, 'max_depth': 16.0, 'min_child_weight': 7.0, 'reg_alpha': 75.0, 'reg_lambda': 0.5666237797241254}
others
# Out:
# {'colsample_bytree': 0.542121153860698,
#  'gamma': 5.465775116244733,
#  'max_depth': 16.0,
#  'min_child_weight': 7.0,
#  'reg_alpha': 75.0,
#  'reg_lambda': 0.5666237797241254}

# %%
important = {'colsample_bytree': 0.7397277174593374, 'gamma': 1.6325285285515658, 'max_depth': 16.0, 'min_child_weight': 7.0, 'reg_alpha': 75.0, 'reg_lambda': 0.24524338576589366}
important
# Out:
# {'colsample_bytree': 0.7397277174593374,
#  'gamma': 1.6325285285515658,
#  'max_depth': 16.0,
#  'min_child_weight': 7.0,
#  'reg_alpha': 75.0,
#  'reg_lambda': 0.24524338576589366}

# %%
MAE important hyper = 0.024623803009575923
biasa = 0.024623803009575923

# %%
Training model 
  Training time : 1.865189552307129 seconds
  Training accuracy : 1.0

Testing model 
  Testing time : 1.7206230163574219 seconds
  Testing accuracy : 0.9712722298221614

  MSE   : 0.036935704514363885
  MAE   : 0.03146374829001368
  MAPE  : 24643500012971.26

Report :
              precision    recall  f1-score   support

         0.0       1.00      0.79      0.88        14
         1.0       0.95      0.90      0.92        60
         2.0       0.97      1.00      0.98       233
         3.0       1.00      0.99      0.99       223
         4.0       0.96      1.00      0.98       165
         5.0       0.93      0.79      0.85        33
         6.0       0.33      0.33      0.33         3

    accuracy                           0.97       731
   macro avg       0.88      0.83      0.85       731
weighted avg       0.97      0.97      0.97       731

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.text(0.5, 0.8, 'Test', color='red', 
        bbox=dict(facecolor='none', edgecolor='red'))

ax.text(0.5, 0.6, 'Test', color='blue', 
        bbox=dict(facecolor='none', edgecolor='blue', pad=10.0))

ax.text(0.5, 0.4, 'Test', color='green', 
        bbox=dict(facecolor='none', edgecolor='green', boxstyle='round'))

ax.text(0.5, 0.2, 'Test', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'))

plt.show()

# %%
Training model 
  Training time : 11.686387062072754 seconds
  Training accuracy : 1.0

Testing model 
  Testing time : 9.636028289794922 seconds
  Testing accuracy : 0.9740082079343365

  MSE   : 0.16121970123301765
  MAE   : 0.025991792065663474
  MAPE  : 30804375016214.074

Report :
              precision    recall  f1-score   support

         0.0       1.00      0.64      0.78        14
         1.0       0.90      0.90      0.90        60
         2.0       0.97      1.00      0.99       233
         3.0       1.00      1.00      1.00       223
         4.0       0.97      1.00      0.99       165
         5.0       0.93      0.85      0.89        33
         6.0       1.00      0.33      0.50         3

    accuracy                           0.97       731
   macro avg       0.97      0.82      0.86       731
weighted avg       0.97      0.97      0.97       731

# %%
Training model 
  Training time : 7.883398532867432 seconds
  Training accuracy : 0.9994128009395185

Testing model 
  Testing time : 7.491009473800659 seconds
  Testing accuracy : 0.9726402188782489

  MSE   : 0.16540792339471233
  MAE   : 0.027359781121751026
  MAPE  : 24643500012971.26

Report :
              precision    recall  f1-score   support

         0.0       1.00      0.71      0.83        14
         1.0       0.92      0.90      0.91        60
         2.0       0.97      1.00      0.99       233
         3.0       1.00      0.99      1.00       223
         4.0       0.96      1.00      0.98       165
         5.0       0.93      0.85      0.89        33
         6.0       1.00      0.33      0.50         3

    accuracy                           0.97       731
   macro avg       0.97      0.83      0.87       731
weighted avg       0.97      0.97      0.97       731

# %%
Training model 
  Training time : 9.179615259170532 seconds
  Training accuracy : 1.0

Testing model 
  Testing time : 7.769275903701782 seconds
  Testing accuracy : 0.9753761969904241

  MSE   : 0.15691973428978245
  MAE   : 0.024623803009575923
  MAPE  : 24643500012971.26

Report :
              precision    recall  f1-score   support

         0.0       1.00      0.71      0.83        14
         1.0       0.92      0.90      0.91        60
         2.0       0.97      1.00      0.99       233
         3.0       1.00      1.00      1.00       223
         4.0       0.97      1.00      0.99       165
         5.0       0.93      0.85      0.89        33
         6.0       1.00      0.33      0.50         3

    accuracy                           0.98       731
   macro avg       0.97      0.83      0.87       731
weighted avg       0.98      0.98      0.97       731

# %%
24	Indoor Operative Temperature	0.115805
20	Indoor Globe Temperature	0.182007
9	Thermal Preference Vote	0.232549

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = 'rev_compare_hyp_rand_60_1per1_30nov.csv'
data = pd.read_csv(data)
data
# Out:
#     Unnamed: 0  featureNum trainAcc_xgb  trainSec_xgb  testAcc_xgb  \
# 0          0.0         1.0  0.527304756      0.379354     0.500684
# 1          1.0         2.0  0.790369935      1.996787     0.533516
# 2          2.0         3.0            1      1.523991     0.965800
# 3          3.0         4.0            1      0.822769     0.964432
# 4          4.0         5.0            1      0.818767     0.975376
# 5          5.0         6.0            1      0.807759     0.971272
# 6          6.0         7.0            1      1.293215     0.975376
# 7          7.0         8.0            1      1.150078     0.976744
# 8          8.0         9.0            1      0.970910     0.972640
# 9          9.0        10.0            1      1.114044     0.974008
# 10        10.0        11.0            1      1.109032     0.972640
# 11        11.0        12.0            1      1.237154     0.974008
# 12        12.0        13.0            1      1.213136     0.974008
# ...

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][:29], data["MSE_xgb"][:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["MSE_svm"][:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["MSE_xgb_hyp"][:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("MSE", **hfont)
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][2:29], data["MSE_xgb"][2:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["MSE_svm"][2:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["MSE_xgb_hyp"][2:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("MSE", **hfont)
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][:29], data["MAE_xgb"][:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["MAE_svm"][:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["MAE_xgb_hyp"][:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("MAE", **hfont)
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][2:29], data["MAE_xgb"][2:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["MAE_svm"][2:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["MAE_xgb_hyp"][2:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("MAE", **hfont)
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][:29], data["testAcc_xgb"][:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["testAcc_svm"][:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][:29], data["testAcc_xgb_hyp"][:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("Accuracy", **hfont)
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(10,8), dpi=100)
plt.plot(data["featureNum"][2:29], data["testAcc_xgb"][2:29], label = "XGBoost", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["testAcc_svm"][2:29], label = "SVM", marker = ".", markersize = 10)
plt.plot(data["featureNum"][2:29], data["testAcc_xgb_hyp"][2:29], label = "XGBoost With Hyperparameter", marker = ".", markersize = 10)

hfont = {'fontname':'Times New Roman',
        'size'   : 12
        }

plt.xlabel("#Feature(s)", **hfont)
plt.ylabel("Accuracy", **hfont)
plt.legend()
plt.show()
